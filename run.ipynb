# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# %%
df=pd.DataFrame(pd.read_csv("Creditcard_data.csv"))
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      1
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df=df.drop(["Time"],axis=1)

# %%
df['Amount'] = StandardScaler().fit_transform(np.array(df['Amount']).reshape(-1, 1))
X=df.iloc[:,:29]
y=df['Class']

# %%
sm = SMOTE(random_state = 42)
X_train_res, y_train_res = sm.fit_resample(X,y)

# %%
print(X_train_res)
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  0.732725  0.294748  0.507514  0.390657  0.256317 -0.259660  0.128639
# 1522  0.369865  0.317349  0.777039  0.345216  0.411455 -0.399783  0.292584
# 1523 -0.584309  1.176129 -0.683517  2.397070 -0.449180 -1.253959 -1.266244
# 1524 -0.203036 -0.839418  0.569075  1.234286  0.215744 -1.068413  0.167775
# 1525 -0.928586  0.275476  0.858439 -0.311741  0.876962 -0.048948  0.281257
#
#             V8        V9       V10  ...       V20       V21       V22  \
# 0     0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838
# 1     0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672
# 2     0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679
# 3     0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274
# 4    -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521  0.032757 -0.230885 -0.255295  ... -0.079739 -0.162507 -0.439410
# 1522 -0.008612 -0.211491 -0.325096  ... -0.088160 -0.112505 -0.281930
# 1523  0.619287 -1.411234 -1.566287  ...  0.026801  0.127377 -0.421421
# 1524 -0.157032 -0.068671 -0.471191  ...  0.660366  0.034387 -0.402548
# 1525  0.140124 -0.042028 -0.100473  ... -0.017987 -0.156844 -0.276919
#
#            V23       V24       V25       V26       V27       V28    Amount
# 0    -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.409447
# 1     0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.333712
# 2     0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.567910
# 3    -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.277334
# 4    -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  0.006685
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  0.023482 -0.182778  0.215672  0.000334 -0.029659 -0.015703 -0.335564
# 1522 -0.038010 -0.058644  0.254004 -0.098898 -0.045999 -0.039750 -0.337027
# 1523 -0.177820  0.329513  0.127557  0.137569  0.123334 -0.058909 -0.340727
# 1524  0.551340  0.124648  0.237602  0.013278 -0.101169  0.032544  0.569194
# 1525 -0.077318 -0.741016 -0.806194  0.166608 -0.087265 -0.109225 -0.342283
#
# [1526 rows x 29 columns]

# %%
df_new=pd.concat([pd.DataFrame(X_train_res),pd.DataFrame(y_train_res)],axis=1)
df_new
X=df_new.iloc[:,:29]
y=df_new['Class']
df_new
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  0.732725  0.294748  0.507514  0.390657  0.256317 -0.259660  0.128639
# 1522  0.369865  0.317349  0.777039  0.345216  0.411455 -0.399783  0.292584
# 1523 -0.584309  1.176129 -0.683517  2.397070 -0.449180 -1.253959 -1.266244
# 1524 -0.203036 -0.839418  0.569075  1.234286  0.215744 -1.068413  0.167775
# 1525 -0.928586  0.275476  0.858439 -0.311741  0.876962 -0.048948  0.281257
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1     0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 2     0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 3     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 4    -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# ...        ...       ...       ...  ...       ...       ...       ...
#
0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1272  0.010009  0.249162 -0.030183 -0.142702  0.033427  1.051125      1
# 1127 -0.185381  0.179372  0.118770 -0.011970  0.018393 -0.335314      1
# 968  -0.226591  0.175302  0.120694 -0.011379  0.017420 -0.333712      1
# 830  -0.342504  0.163132  0.125764 -0.008358  0.015283 -0.333735      1
# 936   0.346236  0.233624  0.054067 -0.028239  0.019418 -0.340901      1
#
# [384 rows x 30 columns]

# %%
x=sample_df.iloc[:,:29]
y=sample_df['Class']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

sample_accuracy=[]

GNB = GaussianNB()
GNB.fit(X_train, y_train)
y_pred = GNB.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
sample_accuracy.append(accuracy_score(y_test, y_pred)*100)

clf = RandomForestClassifier(n_estimators = 100)  
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
sample_accuracy.append(accuracy_score(y_test, y_pred)*100)

xg = xgb.XGBClassifier()
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
sample_accuracy.append(accuracy_score(y_test, y_pred)*100)

adb = AdaBoostClassifier()
adb_model = adb.fit(X_train,y_train)
y_pred = adb_model.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
sample_accuracy.append(accuracy_score(y_test, y_pred)*100)

classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
sample_accuracy.append(accuracy_score(y_test, y_pred)*100)
# Out:
# 80.51948051948052
# 99.35064935064936
# 98.05194805194806
# 96.75324675324676
# 92.20779220779221

# %%
n1=(1.65**2)*0.5*0.5/((0.06/2)**2)
n1
# Out:
# 756.2499999999999

# %%
stratified_df=df_new.groupby('Class', group_keys=False).apply(lambda x: x.sample(int(n1)))
stratified_df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 690  -0.608941  0.961271  0.978330 -0.375420  0.955270 -0.111386  1.145462
# 311   1.081027 -0.139455  0.483881  0.642057 -0.186845  0.538283 -0.302749
# 501   1.240600  0.747735 -0.214136  1.301475  0.124740 -1.172183  0.371059
# 466   0.779820 -0.415808  0.088185  1.348066 -0.066415  0.414045  0.246647
# 372  -0.689738  1.086091  1.260978 -0.386675  0.023899 -1.138914  0.752138
# ...        ...       ...       ...       ...       ...       ...       ...
# 1000  1.255551  0.353573  0.303496  0.692551 -0.368360 -1.069625  0.088484
# 1487 -0.343588  0.361788  1.306977  0.255870  0.716488 -0.675292  0.614931
# 1149  0.081707  0.800252 -0.396290  1.572773 -0.124434 -0.508220 -0.857722
# 1475 -2.478172 -1.766565  1.131178  1.012604  1.169531 -0.729908  0.301100
# 1048  1.059373  0.383513  0.327216  0.597423 -0.173778 -0.851491  0.121462
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 690  -0.070023 -0.523790 -0.775379  ...  0.034309 -0.010383 -0.425615
# 311   0.315920  0.277328 -0.102329  ... -0.124039 -0.190064  0.057896
# 501  -0.306401 -0.246672 -0.597784  ... -0.039413  0.010700 -0.132261
# 466   0.072639 -0.051965 -0.059674  ...  0.049283 -0.059196 -0.288411
# 372  -0.027374 -0.032902 -0.559840  ... -0.230010 -0.747300  0.011255
# ...        ...       ...       ...  ...       ...       ...       ...
# 1000 -0.204533  0.030448 -0.283389  ... -0.287425 -0.829948  0.127988
# 1487 -0.089952 -0.173358 -0.462339  ... -0.014191  0.027706 -0.158914
# 1149  0.499040 -1.052111 -0.992375  ...  0.009622 -0.447435 -0.078188
# 1475  0.022506 -0.143398 -0.504042  ...  0.297231  0.163609  0.666375
# 1048 -0.146175  0.008969 -0.259445  ... -0.261303 -0.758077  0.131878
#
#            V24       V25       V26       V27       V28    Amount  Class
# 690  -1.022448  0.613098 -0.401181  0.051356  0.083632 -0.149807      0
# 311  -0.269354  0.253835  0.311886  0.001591 -0.003468 -0.260120      0
# 501   0.306805  0.728251 -0.331239  0.039024  0.053600 -0.342260      0
# 466  -0.262645  0.626104 -0.331928  0.003473  0.036664  0.652277      0
# 372   0.282653 -0.449785 -0.087427  0.182553  0.202336 -0.317021      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1000  0.340268  0.217121  0.094633 -0.023089  0.030904 -0.335322      1
# 1487  0.185427  0.329372 -0.294008 -0.078127 -0.087030 -0.339903      1
# 1149 -0.130734  0.128313  0.142352  0.076598 -0.035333 -0.338023      1
# 1475 -0.269400  0.013421  0.021735 -0.292786 -0.145908  1.171298      1
# 1048  0.057492 -0.049709  0.091511  0.018869  0.063875 -0.335135      1
#
# [1512 rows x 30 columns]

# %%
x=stratified_df.iloc[:,:29]
y=stratified_df['Class']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

stratified_accuracy=[]

GNB = GaussianNB()
GNB.fit(X_train, y_train)
y_pred = GNB.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
stratified_accuracy.append(accuracy_score(y_test, y_pred)*100)

clf = RandomForestClassifier(n_estimators = 100)  
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
stratified_accuracy.append(accuracy_score(y_test, y_pred)*100)

xg = xgb.XGBClassifier()
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
stratified_accuracy.append(accuracy_score(y_test, y_pred)*100)

adb = AdaBoostClassifier()
adb_model = adb.fit(X_train,y_train)
y_pred = adb_model.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
stratified_accuracy.append(accuracy_score(y_test, y_pred)*100)

classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
stratified_accuracy.append(accuracy_score(y_test, y_pred)*100)
# Out:
# 73.71900826446281
# 99.3388429752066
# 98.84297520661157
# 98.18181818181819
# 92.56198347107438

# %%
def Cluster_Sampling(df, cluster_size, n_clusters):
    N = len(df)
    K = int(N/cluster_size)
    data = None
    for k in range(K):
        sample_k = df.sample(cluster_size)
        sample_k["cluster"] = np.repeat(k,len(sample_k))
        df = df.drop(index = sample_k.index)
        data = pd.concat([data,sample_k],axis = 0)
    random_chosen_clusters = np.random.randint(0,K,size =n_clusters )
    samples = data[data.cluster.isin(random_chosen_clusters)]
    return(samples)
cluster_df = Cluster_Sampling(df = df_new, cluster_size = 20, n_clusters = 28)

# %%
x=cluster_df.iloc[:,:29]
y=cluster_df['Class']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

cluster_accuracy=[]

GNB = GaussianNB()
GNB.fit(X_train, y_train)
y_pred = GNB.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
cluster_accuracy.append(accuracy_score(y_test, y_pred)*100)

clf = RandomForestClassifier(n_estimators = 100)  
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
cluster_accuracy.append(accuracy_score(y_test, y_pred)*100)

xg = xgb.XGBClassifier()
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
cluster_accuracy.append(accuracy_score(y_test, y_pred)*100)

adb = AdaBoostClassifier()
adb_model = adb.fit(X_train,y_train)
y_pred = adb_model.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
cluster_accuracy.append(accuracy_score(y_test, y_pred)*100)

classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
cluster_accuracy.append(accuracy_score(y_test, y_pred)*100)
# Out:
# 71.35416666666666
# 97.91666666666666
# 92.70833333333334
# 96.35416666666666
# 90.10416666666666

# %%
def systematic_sampling(df, step):
 
    indexes = np.arange(0, len(df), step=step)
    systematic_sample = df.iloc[indexes]
    return systematic_sample

systematic_df = systematic_sampling(df_new, 5)

# %%
x=systematic_df.iloc[:,:29]
y=systematic_df['Class']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

systematic_accuracy=[]

GNB = GaussianNB()
GNB.fit(X_train, y_train)
y_pred = GNB.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
systematic_accuracy.append(accuracy_score(y_test, y_pred)*100)

clf = RandomForestClassifier(n_estimators = 100)  
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
systematic_accuracy.append(accuracy_score(y_test, y_pred)*100)

xg = xgb.XGBClassifier()
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
systematic_accuracy.append(accuracy_score(y_test, y_pred)*100)

adb = AdaBoostClassifier()
adb_model = adb.fit(X_train,y_train)
y_pred = adb_model.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
systematic_accuracy.append(accuracy_score(y_test, y_pred)*100)

classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
systematic_accuracy.append(accuracy_score(y_test, y_pred)*100)
# Out:
# 78.86178861788618
# 99.1869918699187
# 99.1869918699187
# 96.7479674796748
# 91.05691056910568

# %%
stratified_df=df_new.groupby('Class', group_keys=False).apply(lambda x: x.sample(int(n1)))
multistage_df = stratified_df.sample(int(n) , random_state=42)

# %%
x=multistage_df.iloc[:,:29]
y=multistage_df['Class']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=1)

multistage_accuracy=[]

GNB = GaussianNB()
GNB.fit(X_train, y_train)
y_pred = GNB.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
multistage_accuracy.append(accuracy_score(y_test, y_pred)*100)

clf = RandomForestClassifier(n_estimators = 100)  
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
multistage_accuracy.append(accuracy_score(y_test, y_pred)*100)

xg = xgb.XGBClassifier()
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
multistage_accuracy.append(accuracy_score(y_test, y_pred)*100)

adb = AdaBoostClassifier()
adb_model = adb.fit(X_train,y_train)
y_pred = adb_model.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
multistage_accuracy.append(accuracy_score(y_test, y_pred)*100)

classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test, y_pred)*100)
multistage_accuracy.append(accuracy_score(y_test, y_pred)*100)
# Out:
# 81.16883116883116
# 98.05194805194806
# 98.05194805194806
# 96.75324675324676
# 87.66233766233766

# %%
Models=['Gaussian Naive Bayes','Random Forest Classifier','XGBoost Classifier','AdaBoost Classifier','Logistic Regression Classifier']
Accuracy=pd.DataFrame(Models)

# %%
Accuracy['Simple Random Sampling']=sample_accuracy
Accuracy['Stratified Sampling']=stratified_accuracy
Accuracy['Cluster Sampling']=cluster_accuracy
Accuracy['Systematic Sampling']=systematic_accuracy
Accuracy['Multi-Stage Sampling']=multistage_accuracy

# %%
Accuracy
# Out:
#                                 0  Simple Random Sampling  \
# 0            Gaussian Naive Bayes               80.519481
# 1        Random Forest Classifier               99.350649
# 2              XGBoost Classifier               98.051948
# 3             AdaBoost Classifier               96.753247
# 4  Logistic Regression Classifier               92.207792
#
#    Stratified Sampling  Cluster Sampling  Systematic Sampling  \
# 0            73.719008         71.354167            78.861789
# 1            99.338843         97.916667            99.186992
# 2            98.842975         92.708333            99.186992
# 3            98.181818         96.354167            96.747967
# 4            92.561983         90.104167            91.056911
#
#    Multi-Stage Sampling
# 0             81.168831
# 1             98.051948
# 2             98.051948
# 3             96.753247
# 4             87.662338
